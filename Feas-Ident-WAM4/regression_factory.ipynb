# %%
datafolder = 'data/'
tmpfolder = 'tmp/'
from sympy import init_printing
init_printing()

# %matplotlib inline
import sympybotics

# %%
wam_name = 'zeus' # or 'slax' or 'ares' or 'all'

dataset_path_prefix = f'residual_data/{wam_name}_combined_datasets__joint_'
dataset_filetype = '.dat'
joint_i = '0'

dataset_path = dataset_path_prefix + joint_i + dataset_filetype

# %%
# open the dataset and model it directly since it has already been preprocessed and is already the residual
# just get the residual to be 0
import pan
df = pd.read_csv(dataset_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 # open the dataset and model it directly since it has already been preprocessed and is already the residual
#       2 # just get the residual to be 0
# ----> 4 df = pd.read_csv(dataset_path)
#
# NameError: name 'pd' is not defined
